# %% [markdown]
# <a href="https://colab.research.google.com/github/abebual/Timeliness_analysis/blob/master/abebual_json_based_data_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1: JSON Based Data Exercise,
# auther: Abebual Demilew
# ****
# + Based on the World Bank dataset from a school quality improvement project in Ethiopia.
# + Part of Springboard Data Science Career Track
# + Designed to excercise with packages for dealign with JSON
# + Data outputs are meant for learning practice, not intended for quotation.
# ****

# %%
import os
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt

# %% [markdown]
# I will need to mount my Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cwd=os.getcwd()
cwd
# Out:
# '/content'

# %%
# !ls "/content/gdrive/My Drive/data_wrangling_json"
# Out:
# data  index.html  __MACOSX  sliderule_dsi_json_exercise.ipynb

# %%
json_path=os.path.expanduser('~/content/gdrive/My Drive/data_wrangling_json/data/world_bank_projects.json')

# %%
# !wget -cq https://www.springboard.com/workshops/data-science-career-track/learn/#/curriculum/2624
# !unzip -qq data_wrangling_json
# Out:
# unzip:  cannot find or open data_wrangling_json, data_wrangling_json.zip or data_wrangling_json.ZIP.

# %%
# load json as string
json_file = '/content/gdrive/My Drive/data_wrangling_json/data/world_bank_projects.json'
with open(json_file, 'r') as wb_json:
  json_data=json.load(wb_json)

# %%
type(json_data)
# Out:
# list

# %%
os.listdir()
# Out:
# ['.config', 'index.html', 'gdrive', 'sample_data']

# %%
wb_json=json.load((open('/content/gdrive/My Drive/data_wrangling_json/data/world_bank_projects.json')))

# %%
json_normalize(wb_json)
# Out:
#                      _id.$oid  ...                                                url
# 0    52b213b38594d8a2be17c780  ...  http://www.worldbank.org/projects/P129828/ethi...
# 1    52b213b38594d8a2be17c781  ...  http://www.worldbank.org/projects/P144674?lang=en
# 2    52b213b38594d8a2be17c782  ...  http://www.worldbank.org/projects/P145310?lang=en
# 3    52b213b38594d8a2be17c783  ...  http://www.worldbank.org/projects/P144665?lang=en
# 4    52b213b38594d8a2be17c784  ...  http://www.worldbank.org/projects/P144933/seco...
# 5    52b213b38594d8a2be17c785  ...  http://www.worldbank.org/projects/P146161?lang=en
# 6    52b213b38594d8a2be17c786  ...  http://www.worldbank.org/projects/P121185/firs...
# 7    52b213b38594d8a2be17c787  ...  http://www.worldbank.org/projects/P127033/chin...
# 8    52b213b38594d8a2be17c788  ...  http://www.worldbank.org/projects/P130164/raja...
# 9    52b213b38594d8a2be17c789  ...  http://www.worldbank.org/projects/P130903?lang=en
# 10   52b213b38594d8a2be17c78a  ...  http://www.worldbank.org/projects/P145339?lang=en
# 11   52b213b38594d8a2be17c78b  ...  http://www.worldbank.org/projects/P146653?lang=en
# 12   52b213b38594d8a2be17c78c  ...  http://www.worldbank.org/projects/P144140/gh-e...
# 13   52b213b38594d8a2be17c78d  ...  http://www.worldbank.org/projects/P130975/timo...
# 14   52b213b38594d8a2be17c78e  ...  http://www.worldbank.org/projects/P144832?lang=en
# 15   52b213b38594d8a2be17c78f  ...  http://www.worldbank.org/projects/P145545?lang=en
# 16   52b213b38594d8a2be17c790  ...  http://www.worldbank.org/projects/P145938?lang=en
# 17   52b213b38594d8a2be17c791  ...  http://www.worldbank.org/projects/P132616?lang=en
# 18   52b213b38594d8a2be17c792  ...  http://www.worldbank.org/projects/P146271?lang=en
# 19   52b213b38594d8a2be17c793  ...  http://www.worldbank.org/projects/P143979?lang=en
# 20   52b213b38594d8a2be17c794  ...  http://www.worldbank.org/projects/P132577?lang=en
# 21   52b213b38594d8a2be17c795  ...  http://www.worldbank.org/projects/P145359?lang=en
# 22   52b213b38594d8a2be17c796  ...  http://www.worldbank.org/projects/P147689?lang=en
# 23   52b213b38594d8a2be17c797  ...  http://www.worldbank.org/projects/P146109?lang=en
# 24   52b213b38594d8a2be17c798  ...  http://www.worldbank.org/projects/P122812/thir...
# 25   52b213b38594d8a2be17c799  ...  http://www.worldbank.org/projects/P123933/capt...
# 26   52b213b38594d8a2be17c79a  ...  http://www.worldbank.org/projects/P143025/lao-...
# 27   52b213b38594d8a2be17c79b  ...  http://www.worldbank.org/projects/P145057/paci...
# 28   52b213b38594d8a2be17c79c  ...  http://www.worldbank.org/projects/P146021?lang=en
# 29   52b213b38594d8a2be17c79d  ...  http://www.worldbank.org/projects/P146098?lang=en
# ..                        ...  ...                                                ...
# 470  52b213b38594d8a2be17c956  ...  http://www.worldbank.org/projects/P129654/libe...
# 471  52b213b38594d8a2be17c957  ...  http://www.worldbank.org/projects/P131263/rura...
# 472  52b213b38594d8a2be17c958  ...  http://www.worldbank.org/projects/P131631/repo...
# 473  52b213b38594d8a2be17c959  ...  http://www.worldbank.org/projects/P132679/land...
# 474  52b213b38594d8a2be17c95a  ...  http://www.worldbank.org/projects/P112901/pk-p...
# 475  52b213b38594d8a2be17c95b  ...  http://www.worldbank.org/projects/P118916/infr...
# 476  52b213b38594d8a2be17c95c  ...  http://www.worldbank.org/projects/P125996/dist...
# 477  52b213b38594d8a2be17c95d  ...  http://www.worldbank.org/projects/P126962/addi...
# 478  52b213b38594d8a2be17c95e  ...  http://www.worldbank.org/projects/P131266/punj...
# 479  52b213b38594d8a2be17c95f  ...  http://www.worldbank.org/projects/P130412/stre...
# 480  52b213b38594d8a2be17c960  ...  http://www.worldbank.org/projects/P131881/zamb...
# 481  52b213b38594d8a2be17c961  ...  http://www.worldbank.org/projects/P121731/icds...
# 482  52b213b38594d8a2be17c962  ...  http://www.worldbank.org/projects/P122486/karn...
# 483  52b213b38594d8a2be17c963  ...  http://www.worldbank.org/projects/P124041/hima...
# 484  52b213b38594d8a2be17c964  ...  http://www.worldbank.org/projects/P132238/mult...
# 485  52b213b38594d8a2be17c965  ...  http://www.worldbank.org/projects/P131204/capa...
# 486  52b213b38594d8a2be17c966  ...  http://www.worldbank.org/projects/P132097/5m-d...
# 487  52b213b38594d8a2be17c967  ...  http://www.worldbank.org/projects/P121116/sust...
# 488  52b213b38594d8a2be17c968  ...  http://www.worldbank.org/projects/P126465/rio-...
# 489  52b213b38594d8a2be17c969  ...  http://www.worldbank.org/projects/P128763/papu...
# 490  52b213b38594d8a2be17c96a  ...  http://www.worldbank.org/projects/P131860/stre...
# 491  52b213b38594d8a2be17c96b  ...  http://www.worldbank.org/projects/P123322/wate...
# 492  52b213b38594d8a2be17c96c  ...  http://www.worldbank.org/projects/P128096/paki...
# 493  52b213b38594d8a2be17c96d  ...  http://www.worldbank.org/projects/P132138/revi...
# 494  52b213b38594d8a2be17c96e  ...  http://www.worldbank.org/projects/P129177/nepa...
# 495  52b213b38594d8a2be17c96f  ...  http://www.worldbank.org/projects/P127299/tech...
# 496  52b213b38594d8a2be17c970  ...  http://www.worldbank.org/projects/P125298/lao-...
# 497  52b213b38594d8a2be17c971  ...  http://www.worldbank.org/projects/P128309/seco...
# 498  52b213b38594d8a2be17c972  ...  http://www.worldbank.org/projects/P117243/sust...
# 499  52b213b38594d8a2be17c973  ...  http://www.worldbank.org/projects/P126321/keny...
#
# [500 rows x 55 columns]

# %%
wb_df=pd.read_json('/content/gdrive/My Drive/data_wrangling_json/data/world_bank_projects.json')
wb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 50 columns):
# _id                         500 non-null object
# approvalfy                  500 non-null int64
# board_approval_month        500 non-null object
# boardapprovaldate           500 non-null object
# borrower                    485 non-null object
# closingdate                 370 non-null object
# country_namecode            500 non-null object
# countrycode                 500 non-null object
# countryname                 500 non-null object
# countryshortname            500 non-null object
# docty                       446 non-null object
# envassesmentcategorycode    430 non-null object
# grantamt                    500 non-null int64
# ibrdcommamt                 500 non-null int64
# id                          500 non-null object
# idacommamt                  500 non-null int64
# impagency                   472 non-null object
# lendinginstr                495 non-null object
# lendinginstrtype            495 non-null object
# lendprojectcost             500 non-null int64
# majorsector_percent         500 non-null object
# mjsector_namecode           500 non-null object
# mjtheme                     491 non-null object
# mjtheme_namecode            500 non-null object
# mjthemecode                 500 non-null object
# prodline                    500 non-null object
# prodlinetext                500 non-null object
# productlinetype             500 non-null object
# project_abstract            362 non-null object
# project_name                500 non-null object
# projectdocs                 446 non-null object
# projectfinancialtype        500 non-null object
# projectstatusdisplay        500 non-null object
# regionname                  500 non-null object
# sector                      500 non-null object
# sector1                     500 non-null object
# sector2                     380 non-null object
# sector3                     265 non-null object
# sector4                     174 non-null object
# sector_namecode             500 non-null object
# sectorcode                  500 non-null object
# source                      500 non-null object
# status                      500 non-null object
# supplementprojectflg        498 non-null object
# theme1                      500 non-null object
# theme_namecode              491 non-null object
# themecode                   491 non-null object
# totalamt                    500 non-null int64
# totalcommamt                500 non-null int64
# url                         500 non-null object
# dtypes: int64(7), object(43)
# memory usage: 195.4+ KB

# %% [markdown]
# ****
# ## JSON exercise
#
# Using the 'world_bank_projects.json',
# 1. Find the 10 countries with most projects
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %% [markdown]
# ## 10 countries with most projects

# %%
wb_df['countryname'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       Federal Democratic Republic of Ethiopia
# 1                           Republic of Tunisia
# 2                                        Tuvalu
# 3                             Republic of Yemen
# 4                            Kingdom of Lesotho
# 5                             Republic of Kenya
# 6                             Republic of India
# 7                    People's Republic of China
# 8                             Republic of India
# 9                            Kingdom of Morocco
# 10                      Republic of South Sudan
# 11                            Republic of India
# 12                            Republic of Ghana
# 13           Democratic Republic of Timor-Leste
# 14                  Hashemite Kingdom of Jordan
# 15                                        Samoa
# 16                                        Samoa
# 17                       Republic of Madagascar
# 18                          Kingdom of Cambodia
# 19                           Kingdom of Morocco
# 20                              Kyrgyz Republic
# 21                                        Nepal
# 22                  Hashemite Kingdom of Jordan
# 23                       Republic of Tajikistan
# 24                       Republic of Azerbaijan
# 25                        East Asia and Pacific
# 26             Lao People's Democratic Republic
# 27                              Pacific Islands
# 28                              Solomon Islands
# 29                       Republic of Mozambique
#                          ...
# 470                         Republic of Liberia
# 471             People's Republic of Bangladesh
# 472                         Republic of Armenia
# 473                         Republic of Albania
# 474                Islamic Republic of Pakistan
# 475                       Republic of Indonesia
# 476               Socialist Republic of Vietnam
# 477                      Republic of Uzbekistan
# 478                Islamic Republic of Pakistan
# 479                       Republic of Guatemala
# 480                          Republic of Zambia
# 481                           Republic of India
# 482                           Republic of India
# 483                           Republic of India
# 484                 Republic of the Philippines
# 485                                    Mongolia
# 486                Middle East and North Africa
# 487                       United Mexican States
# 488               Federative Republic of Brazil
# 489    The Independent State of Papua New Guine
# 490                                       Nepal
# 491                          West Bank and Gaza
# 492                Islamic Republic of Pakistan
# 493             People's Republic of Bangladesh
# 494                                       Nepal
# 495                                     Jamaica
# 496            Lao People's Democratic Republic
# 497                          Republic of Guinea
# 498                       Republic of Indonesia
# 499                           Republic of Kenya
# Name: countryname, Length: 500, dtype: object>

# %%
projects=wb_df.groupby('countryname')['project_name'].count()
projects.head()
# Out:
# countryname
# Africa                    11
# Antigua and Barbuda        1
# Arab Republic of Egypt     2
# Argentine Republic         2
# Bosnia and Herzegovina     1
# Name: project_name, dtype: int64

# %%
#Top 10 countries for most projects are ... wait for it:
projects_sorted=projects.sort_values(ascending=False)
projects_sorted.head(10)
# Out:
# countryname
# People's Republic of China         19
# Republic of Indonesia              19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# Nepal                              12
# People's Republic of Bangladesh    12
# Kingdom of Morocco                 12
# Africa                             11
# Republic of Mozambique             11
# Name: project_name, dtype: int64

# %% [markdown]
# ## 10 major project themes

# %%
theme=wb_df['mjtheme_namecode']

# %%
theme[0:4]
# Out:
# 0    [{'code': '8', 'name': 'Human development'}, {...
# 1    [{'code': '1', 'name': 'Economic management'},...
# 2    [{'code': '5', 'name': 'Trade and integration'...
# 3    [{'code': '7', 'name': 'Social dev/gender/incl...
# Name: mjtheme_namecode, dtype: object

# %% [markdown]
# It looks like 'mjtheme_namecode' is a nested dictionary presented as a list. I will need to convert it to a string to make it analyis friendly.

# %%
type(theme)
# Out:
# pandas.core.series.Series

# %%
theme_l_list=theme.tolist()

# %%
theme_l_list[0:2]
# Out:
# [[{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}],
#  [{'code': '1', 'name': 'Economic management'},
#   {'code': '6', 'name': 'Social protection and risk management'}]]

# %%
theme_list=[j for i in theme_l_list for j in i]

# %%
theme_list[0:5]
# Out:
# [{'code': '8', 'name': 'Human development'},
#  {'code': '11', 'name': ''},
#  {'code': '1', 'name': 'Economic management'},
#  {'code': '6', 'name': 'Social protection and risk management'},
#  {'code': '5', 'name': 'Trade and integration'}]

# %%
df_theme=pd.DataFrame(theme_list)

# %%
df_theme.head()
# Out:
#   code                                   name
# 0    8                      Human development
# 1   11
# 2    1                    Economic management
# 3    6  Social protection and risk management
# 4    5                  Trade and integration

# %%
#change variable name to make it readable
#df_x=df_theme.groupby(['Project_theme_code', 'Project_theme_name'])
df_theme.columns=['Project_theme_code', 'Project_theme_name']

# %%
df_theme.head()
# Out:
#   Project_theme_code                     Project_theme_name
# 0                  8                      Human development
# 1                 11
# 2                  1                    Economic management
# 3                  6  Social protection and risk management
# 4                  5                  Trade and integration

# %%
df_theme_g=df_theme.groupby(['Project_theme_code','Project_theme_name']).size().reset_index().rename(columns={0:'count'})

# %%
df_theme_g
# Out:
#    Project_theme_code                            Project_theme_name  count
# 0                   1                                                    5
# 1                   1                           Economic management     33
# 2                  10                                                   14
# 3                  10                             Rural development    202
# 4                  11                                                   27
# 5                  11  Environment and natural resources management    223
# 6                   2                                                   15
# 7                   2                      Public sector governance    184
# 8                   3                                                    3
# 9                   3                                   Rule of law     12
# 10                  4                                                   16
# 11                  4      Financial and private sector development    130
# 12                  5                                                    5
# 13                  5                         Trade and integration     72
# 14                  6                                                   10
# 15                  6         Social protection and risk management    158
# 16                  7                                                   11
# 17                  7                   Social dev/gender/inclusion    119
# 18                  8                                                   13
# 19                  8                             Human development    197
# 20                  9                                                    3
# 21                  9                             Urban development     47

# %%
df_theme_sorted=df_theme_g.sort_values('count', ascending=False)

# %%
#The top 10 major project themes are: 
df_theme_sorted.head(10)
# Out:
#    Project_theme_code                            Project_theme_name  count
# 5                  11  Environment and natural resources management    223
# 3                  10                             Rural development    202
# 19                  8                             Human development    197
# 7                   2                      Public sector governance    184
# 15                  6         Social protection and risk management    158
# 11                  4      Financial and private sector development    130
# 17                  7                   Social dev/gender/inclusion    119
# 13                  5                         Trade and integration     72
# 21                  9                             Urban development     47
# 1                   1                           Economic management     33

# %% [markdown]
# ##Create a dataframe with the missing names filled in.

# %%
df_theme.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 2 columns):
# Project_theme_code    1499 non-null object
# Project_theme_name    1499 non-null object
# dtypes: object(2)
# memory usage: 23.5+ KB

# %%
theme_nan=df_theme.replace('', np.nan, regex=True)
theme_nan
# Out:
#      Project_theme_code                            Project_theme_name
# 0                     8                             Human development
# 1                    11                                           NaN
# 2                     1                           Economic management
# 3                     6         Social protection and risk management
# 4                     5                         Trade and integration
# 5                     2                      Public sector governance
# 6                    11  Environment and natural resources management
# 7                     6         Social protection and risk management
# 8                     7                   Social dev/gender/inclusion
# 9                     7                   Social dev/gender/inclusion
# 10                    5                         Trade and integration
# 11                    4      Financial and private sector development
# 12                    6         Social protection and risk management
# 13                    6                                           NaN
# 14                    2                      Public sector governance
# 15                    4      Financial and private sector development
# 16                   11  Environment and natural resources management
# 17                    8                                           NaN
# 18                   10                             Rural development
# 19                    7                                           NaN
# 20                    2                      Public sector governance
# 21                    2                      Public sector governance
# 22                    2                      Public sector governance
# 23                   10                             Rural development
# 24                    2                                           NaN
# 25                   10                             Rural development
# 26                    6         Social protection and risk management
# 27                    6         Social protection and risk management
# 28                   11  Environment and natural resources management
# 29                    4                                           NaN
# ...                 ...                                           ...
# 1469                  8                             Human development
# 1470                  9                             Urban development
# 1471                  6         Social protection and risk management
# 1472                  6         Social protection and risk management
# 1473                  9                             Urban development
# 1474                  2                      Public sector governance
# 1475                  2                      Public sector governance
# 1476                 10                             Rural development
# 1477                 11                                           NaN
# 1478                  8                             Human development
# 1479                  7                   Social dev/gender/inclusion
# 1480                 11  Environment and natural resources management
# 1481                  5                                           NaN
# 1482                  6         Social protection and risk management
# 1483                  8                                           NaN
# 1484                  4      Financial and private sector development
# 1485                  7                   Social dev/gender/inclusion
# 1486                  8                             Human development
# 1487                  5                         Trade and integration
# 1488                  2                      Public sector governance
# 1489                  8                             Human development
# 1490                 10                             Rural development
# 1491                  6                                           NaN
# 1492                 10                             Rural development
# 1493                 10                             Rural development
# 1494                 10                             Rural development
# 1495                  9                             Urban development
# 1496                  8                             Human development
# 1497                  5                         Trade and integration
# 1498                  4      Financial and private sector development
#
# [1499 rows x 2 columns]

# %%
#create dictionary of unique project theme codes and corrosponding project theme names.

# %%
theme_unique=theme_nan.groupby(['Project_theme_code','Project_theme_name']).size().reset_index().rename(columns={0:'count'}) 
theme_unique
# Out:
#    Project_theme_code                            Project_theme_name  count
# 0                   1                           Economic management     33
# 1                  10                             Rural development    202
# 2                  11  Environment and natural resources management    223
# 3                   2                      Public sector governance    184
# 4                   3                                   Rule of law     12
# 5                   4      Financial and private sector development    130
# 6                   5                         Trade and integration     72
# 7                   6         Social protection and risk management    158
# 8                   7                   Social dev/gender/inclusion    119
# 9                   8                             Human development    197
# 10                  9                             Urban development     47

# %%
theme_dict= {'1': 'Economic management',
  '10': 'Rural development',
  '11': 'Environment and natural resources management',
  '2': 'Public sector governance',
  '3': 'Rule of law',
  '4': 'Financial and private sector development',
  '5': 'Trade and integration',
  '6': 'Social protection and risk management',
  '7': 'Social dev/gender/inclusion',
  '8': 'Human development',
  '9': 'Urban development'}

# %%
#replace NAN values using dictionary
df_theme['Project_theme_name'] =  df_theme['Project_theme_code'].replace(theme_dict)
df_theme.head()
# Out:
#   Project_theme_code                            Project_theme_name
# 0                  8                             Human development
# 1                 11  Environment and natural resources management
# 2                  1                           Economic management
# 3                  6         Social protection and risk management
# 4                  5                         Trade and integration

# %%
df_theme
# Out:
#      Project_theme_code                            Project_theme_name
# 0                     8                             Human development
# 1                    11  Environment and natural resources management
# 2                     1                           Economic management
# 3                     6         Social protection and risk management
# 4                     5                         Trade and integration
# 5                     2                      Public sector governance
# 6                    11  Environment and natural resources management
# 7                     6         Social protection and risk management
# 8                     7                   Social dev/gender/inclusion
# 9                     7                   Social dev/gender/inclusion
# 10                    5                         Trade and integration
# 11                    4      Financial and private sector development
# 12                    6         Social protection and risk management
# 13                    6         Social protection and risk management
# 14                    2                      Public sector governance
# 15                    4      Financial and private sector development
# 16                   11  Environment and natural resources management
# 17                    8                             Human development
# 18                   10                             Rural development
# 19                    7                   Social dev/gender/inclusion
# 20                    2                      Public sector governance
# 21                    2                      Public sector governance
# 22                    2                      Public sector governance
# 23                   10                             Rural development
# 24                    2                      Public sector governance
# 25                   10                             Rural development
# 26                    6         Social protection and risk management
# 27                    6         Social protection and risk management
# 28                   11  Environment and natural resources management
# 29                    4      Financial and private sector development
# ...                 ...                                           ...
# 1469                  8                             Human development
# 1470                  9                             Urban development
# 1471                  6         Social protection and risk management
# 1472                  6         Social protection and risk management
# 1473                  9                             Urban development
# 1474                  2                      Public sector governance
# 1475                  2                      Public sector governance
# 1476                 10                             Rural development
# 1477                 11  Environment and natural resources management
# 1478                  8                             Human development
# 1479                  7                   Social dev/gender/inclusion
# 1480                 11  Environment and natural resources management
# 1481                  5                         Trade and integration
# 1482                  6         Social protection and risk management
# 1483                  8                             Human development
# 1484                  4      Financial and private sector development
# 1485                  7                   Social dev/gender/inclusion
# 1486                  8                             Human development
# 1487                  5                         Trade and integration
# 1488                  2                      Public sector governance
# 1489                  8                             Human development
# 1490                 10                             Rural development
# 1491                  6         Social protection and risk management
# 1492                 10                             Rural development
# 1493                 10                             Rural development
# 1494                 10                             Rural development
# 1495                  9                             Urban development
# 1496                  8                             Human development
# 1497                  5                         Trade and integration
# 1498                  4      Financial and private sector development
#
# [1499 rows x 2 columns]
